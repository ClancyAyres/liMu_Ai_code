# %% [markdown]
# # 序列模型
# 使用正弦函数和一些噪声点来生成序列数据，1,2,...,1000

# %%
# %matplotlib inline
import torch
from d2l import torch as d2l

T = 1000

time = torch.arange(1, T+1, dtype = torch.float32)
x = torch.sin(0.01 * time) + torch.normal(0, 0.2, (T,))
d2l.plot(time, [x], 'time', 'x', xlim=[1,1000],figsize=(6,3))

# %%
tau = 4
# 采用马尔可夫假设，此时用前四个样本来预测第五个，T-tau为样本数，tau为特征数
# [996*4]
features = torch.zeros((T - tau, tau))
for i in range(tau):
    features[:,i] = x[i:T - tau + i]
labels = x[tau:].reshape((-1,1))

batch_size = 16
n_train = 600

train_iter = d2l.load_array(
    (
        features[:n_train],
        labels[:n_train],
    ),
        batch_size=batch_size,
        is_train=True
)

# %%
from torch import nn

# 初始化网络权重的函数
def init_weights(m):
    if type(m) == nn.Linear:
        nn.init.xavier_uniform_(m.weight)

# 一个简单的多层感知机
def get_net():
    net = nn.Sequential(nn.Linear(4, 10),
                        nn.ReLU(),
                        nn.Linear(10, 1))
    net.apply(init_weights)
    return net


# 平方损失。注意：MSELoss计算平方误差时不带系数1/2
loss = torch.nn.MSELoss(reduction='none')

# %%
def train(net, train_iter, loss, epochs, lr):
    trainer = torch.optim.Adam(net.parameters(), lr)
    
    for epoch in range(epochs):
        for X, y in train_iter:
            trainer.zero_grad()
            l = loss(net(X), y)
            l.sum().backward()
            trainer.step()
        print(f'epoch {epoch + 1}, '
              f'loss: {d2l.evaluate_loss(net, train_iter, loss):f}')

net = get_net()
train(net, train_iter, loss, 5, 0.01)
# Out:
# epoch 1, loss: 0.060826
# epoch 2, loss: 0.050896
# epoch 3, loss: 0.047826
# epoch 4, loss: 0.047232
# epoch 5, loss: 0.049412

# %%
# 开始预测(data-set分为两部分，前600训练 后400预测)
onestep_preds = net(features)

d2l.plot([time, time[tau:]],
         [x.detach().numpy(), onestep_preds.detach().numpy()], 'time',
         'x', legend=['data', '1-step preds'], xlim=[1, 1000],
         figsize=(6, 3))
